# %% [markdown]
# # EDA(Exploratory Data Analysis)
# ![](./main.jpg)
# - 우리는 왜 지금까지 `pandas`로 데이터를 가공하고, 그런 데이터를 `matplotlib`과 `seaborn`으로 시각화 했을까요?
# - 사실 이러한 과정이 모두 EDA를 위한 것이라고 해도 과언이 아닙니다. EDA는 우리가 불러온 데이터를 전처리하고 분석을 하면서 그 안에서 유의미한 결과를 추출하는 과정을 말합니다.
# - EDA만 잘 해도 우리가 힘들게 머신러닝이나 딥러닝을 돌리지 않아도 충분히 데이터 자체에서 유의미한 인사이트를 추출할 수 있죠. 뿐만 아니라 데이터가 어떻게 생겼는지 EDA를 통해 파악함으로써, 모델을 어떻게 설계해야 할지, 전처리 전략은 어떻게 가져가야할 지 구상할 수 있습니다.
# - 여기까지만 들으셔도 왜 EDA를 꼭 해야하는지 감이 잡히시죠? 아직 감이 안 잡히시는 분들을 위해 예시 하나만 들어드릴게요.
# ```
#     - A와 B는 같은 데이터를 가지고 모델링을 해서 누가누가 더 좋은 성능을 내는지 내기를 했습니다.
#     - A는 EDA부터 차근찬근 진행하였고, B는 EDA를 하지 않고 기본적인 전처리만 하고 모델에 넣었습니다.
#     - 그러나 성능은 A의 것이 훨씬 좋게 나왔습니다. 알고보니 Target Data에 몇몇 Noise가 껴있었고, A는 이를 EDA과정에서 발견하고 가공 후 모델링을 진행했던 것입니다.
#     - A는 그 과정에서 Target Data의 Imbalance도 발견했습니다. A는 이를 보고 loss에 weight를 다르게 주는 방법을 적용하여 B와 같은 모델을 사용했지만 모델이 데이터 불균형에 더 강건하게 학습하도록 만들었습니다.
#     - A는 B와의 내기에서 이겨 행복하게 살았답니다~
# ```
# - 위에서 말하는 Target Data에 노이즈가 어쩌구~ Imbalance가 어쩌구~ Loss의 Weight를 어쩌구~ 는 무시해도 좋습니다. 다만 우리가 꼭 가져가야할 교훈은 EDA를 어떻게 하냐에 따라 모델링의 전략이 달라지고, 데이터 가공이라는 요소는, 우리 모델의 성능을 가장 크게 바꿀 수 있는 변수 중에 하나입니다.
#
# - 머신러닝엔 이런 말이 있습니다. **Garbage in, Garbage out**. 그만큼 우리가 먹이로 주는 데이터의 상태가 모델의 성능을 결정하는 데에 있어 매우 중요한 요소라는 것이죠. 잘 와닿지 않으신다구요? 앞으로 모델링을 하시다보면 왜 이런 말이 나왔는지 아시게 될 거예요 ㅎㅎ
#
# - 그럼 이제부터 데이터 분석 및 모델링의 가장 기본 과정인 EDA를 실습해보겠습니다. 주어진 데이터를 여러분이 지금까지 배우면서 알아낸 기술로 EDA를 진행해볼 겁니다. 시작해보시죠~!
#
# <br>
#
# ---
#
# **알림**
# - 본 컨텐츠는 강의 형식이 아닌, 스스로 공부하시는 분들을 위한 일종의 문제집 입니다.
# - 데이터라는 큰 바다에서 여러분이 쓸 데 없는 시간 낭비 없이 바로바로 핵심을 배우실 수 있도록 커리큘럼을 짜봤습니다.
# - 이 컨텐츠의 문제들만 해결한다고 실력이 오르지 않습니다. 본 컨텐츠의 목적은 문제를 해결하는 과정에서 발생하는 고민과 질문을 통한 실력 향상입니다.
# - 문제에서 절대 떠먹여주지 않습니다. 물고기를 잡아주는 것이 아닌, 물고기를 잡는 방법을 여러분이 이 컨텐츠를 통해 알아가셨으면 합니다.

# %% [markdown]
# # 1. EDA 기본
# - 우리는 이제부터 공공데이터를 활용해서 그 안에서 우리가 어떤 정보를 얻어낼 수 있는지 살펴보고자 합니다. 우리가 지금까지 연습했던 `pandas`와 `시각화 도구`를 어떻게 활용할 수 있을지 한번 알아봅시다!

# %% [markdown]
# ### 1-1 데이터 읽어오기
# [이곳](https://drive.google.com/drive/folders/1xpvgkrmfrE8OZ5pQAbc5g9_3czaOvOTn)에서 데이터를 다운받아 읽어오는 코드를 작성해주세요.
#
# - 파일을 받아보시면, CSV 파일이 여러개가 존재합니다. 이 파일들을 1개의 Data Frame으로 만드는 것이 목표입니다.
# - 단, 만들어진 최종 Data Frame의 index에 주의해주세요! (단순 concat을 시키면 index가... 어떻게 되었죠?)
#
# ```python
# import pandas as pd
# from glob import glob
# import warnings
# warnings.filterwarnings('ignore') # 경고 메세지를 출력 안 하는 코드입니다.
#
# base_dir = "HERE YOUR DIR!" # 알집 풀어주신 곳 폴더를 넣으시면 됩니다.
# file_lst = glob(base_dir + "*.csv")
#
#
# > HERE YOUR CODE!!
#
#
# concat_df
#
# ```
#
# 검색 힌트 : pandas concat, pandas read csv, how to use glob python, pandas concat, pandas reset index
#
# _예시_
# ![](./1-1answer.png)

# %%
import pandas as pd
from glob import glob
import warnings
warnings.filterwarnings('ignore') # 경고 메세지를 출력 안 하는 코드입니다.

base_dir = "03_EDA_실습데이터" # 알집 풀어주신 곳 폴더를 넣으시면 됩니다.
file_lst = glob(base_dir + "/*.csv")

df_lst = []

for dir in file_lst:
    df = pd.read_csv(dir)
    df_lst.append(df)

concat_df = pd.concat(df_lst)
print(concat_df.reset_index())
# Out:
#          index    상가업소번호            상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0            0  25033300      동그라미중고타이어  NaN         D       소매       D23
# 1            1  17174549  세인트존스호텔Ohcrab  NaN         O       숙박       O01
# 2            2  17174079        평창라마다호텔  NaN         O       숙박       O01
# 3            3  17173904    호텔탑스텐스카이라운지  NaN         O       숙박       O01
# 4            4  24412526          레이디가구  NaN         D       소매       D15
# ...        ...       ...            ...  ...       ...      ...       ...
# 2532872  96928  19073226       원조사계절칡냉면  NaN         Q       음식       Q01
# 2532873  96929  19073414           만능수리  NaN         F    생활서비스       F03
# 2532874  96930  19074611          다모아인력  NaN         F    생활서비스       F08
# 2532875  96931  19078175         와이케이푸드  NaN         Q       음식       Q01
# 2532876  96932  19078180           만세건축  NaN         F    생활서비스       F15
#
#           상권업종중분류명 상권업종소분류코드   상권업종소분류명  ...                     건물관리번호  \
# 0        자동차/자동차용품    D23A04      타이어판매  ...  4215011100110960006010791
# 1            호텔/콘도    O01A01      호텔/콘도  ...  4215011300100010001017124
# 2            호텔/콘도    O01A01      호텔/콘도  ...  4276038024102450036000001
# 3            호텔/콘도    O01A01      호텔/콘도  ...  4215035029100920001000002
# 4             가구소매    D15A01     일반가구소매  ...  4213011500111400020035715
# ...            ...       ...        ...  ...                        ...
# 2532872         한식    Q01A01  한식/백반/한정식  ...  4374025028100810002002706
# 2532873  개인/가정용품수리    F03A05   에어컨수리/설치  ...  4313035021102780001042473
# 2532874        대행업    F08A03     고객관리대행  ...  4377035021105480007171082
# 2532875         한식    Q01A01  한식/백반/한정식  ...  4373025037103440002009741
# 2532876       주택수리    F15A02   미장타일도배도장  ...  4377025021106180030000001
#
#              건물명                    도로명주소     구우편번호    신우편번호  동정보  층정보 호정보  \
# 0            NaN          강원도 강릉시 가작로 270  210110.0  25488.0    1  NaN NaN
# 1        세인트존스호텔          강원도 강릉시 창해로 307  210120.0  25467.0  NaN  NaN NaN
# 2            NaN     강원도 평창군 대관령면 오목길 107  232954.0  25342.0  NaN  NaN NaN
# 3            NaN   강원도 강릉시 옥계면 헌화로 455-34  210831.0  25633.0  NaN  NaN NaN
# 4            NaN       강원도 원주시 송삼길 156-19  220150.0  26385.0  NaN  NaN NaN
# ...          ...                      ...       ...      ...  ...  ...  ..
# 2532872      NaN  충청북도 영동군 영동읍 학산영동로 1170  370802.0  29152.0  NaN  NaN NaN
# 2532873      NaN     충청북도 충주시 신니면 용원2길 26  380891.0  27457.0  NaN  NaN NaN
# 2532874      NaN      충청북도 음성군 삼성면 덕정로 75  369833.0  27649.0  NaN    2 NaN
# 2532875       슈퍼     충청북도 옥천군 옥천읍 문장로 104  373805.0  29049.0  NaN  NaN NaN
# 2532876      NaN  충청북도 음성군 음성읍 시장로117번길 8  369807.0  27696.0  NaN  NaN NaN
#
#                  경도         위도
# 0        128.904472  37.770252
# 1        128.920908  37.791299
# 2        128.717971  37.660051
# 3        129.052902  37.654680
# 4        127.917307  37.327668
# ...             ...        ...
# 2532872  127.768971  36.167841
# 2532873  127.735163  36.997242
# 2532874  127.499859  37.020851
# 2532875  127.576315  36.296025
# 2532876  127.690576  36.937684
#
# [2532877 rows x 40 columns]

# %% [markdown]
# ### 1-2 카페만 조회하기
# 1-1에서 만든 Data Frame에서 `상권업종중분류명`이 `커피점/카페`인 데이터들만 조회하는 코드를 작성해주세요.
#
# <br>
#
# ```python
# """~ Codes from 1-1"""
#
# concat_df = > HERE YOUR CODE!!
#
# concat_df = concat_df.reset_index(drop=True) # inplace 쓰셔도 됩니다~
# concat_df
# ```
#
# <br>
#
# 검색 힌트 : pandas indexing, pandas fency indexing
#
# _예시_
# ![](./1-2answer.png)

# %%
import pandas as pd
from glob import glob
import warnings
warnings.filterwarnings('ignore') # 경고 메세지를 출력 안 하는 코드입니다.

base_dir = "03_EDA_실습데이터" # 알집 풀어주신 곳 폴더를 넣으시면 됩니다.
file_lst = glob(base_dir + "/*.csv")

df_lst = []

for dir in file_lst:
    df = pd.read_csv(dir)
    df_lst.append(df)

concat_df = pd.concat(df_lst)

coffee_shops = concat_df.loc[concat_df['상권업종중분류명'] == '커피점/카페',:]
print(coffee_shops)
# Out:
#          상가업소번호       상호명     지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 13     20778927  키즈까페아이사랑     NaN         Q       음식       Q12   커피점/카페
# 39     20658047        힐링     NaN         Q       음식       Q12   커피점/카페
# 56     15589162       드롭탑  속초엑스포점         Q       음식       Q12   커피점/카페
# 83     20762517     상유재카페     NaN         Q       음식       Q12   커피점/카페
# 269    20527333      수정다방     NaN         Q       음식       Q12   커피점/카페
# ...         ...       ...     ...       ...      ...       ...      ...
# 96890  19074967      카페니프     NaN         Q       음식       Q12   커피점/카페
# 96891  19076347  130에스프레소     NaN         Q       음식       Q12   커피점/카페
# 96892  19076952        카페  올림푸스보드         Q       음식       Q12   커피점/카페
# 96905  19073995        설빙     호암점         Q       음식       Q12   커피점/카페
# 96907  19076763      카페천국     NaN         Q       음식       Q12   커피점/카페
#
#       상권업종소분류코드     상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# 13       Q12A01  커피전문점/카페/다방   I56220  ...  4215012500107080003000001
# 39       Q12A01  커피전문점/카페/다방   I56220  ...  4213010700116690010000001
# 56       Q12A01  커피전문점/카페/다방   I56220  ...  4221010800115470008000001
# 83       Q12A01  커피전문점/카페/다방   I56220  ...  4277025021102170001011447
# 269      Q12A01  커피전문점/카페/다방   I56220  ...  4282025321101580104018419
# ...         ...          ...      ...  ...                        ...
# 96890    Q12A01  커피전문점/카페/다방   I56220  ...  4311313800103950031000001
# 96891    Q12A01  커피전문점/카페/다방   I56220  ...  4311111400102130002035631
# 96892    Q12A04       보드게임카페   I56220  ...  4311111500116350000038472
# 96905    Q12A01  커피전문점/카페/다방   I56220  ...  4313010700109910000000001
# 96907    Q12A01  커피전문점/카페/다방   I56220  ...  4311325031111380000000001
#
#              건물명                        도로명주소     구우편번호    신우편번호  동정보  층정보  \
# 13           NaN           강원도 강릉시 성덕포남로 45-8  210938.0  25615.0  NaN    2
# 39           NaN            강원도 원주시 단관길 114-6  220965.0  26490.0  NaN  NaN
# 56           NaN              강원도 속초시 엑스포로 45  217813.0  24872.0  NaN  NaN
# 83           NaN         강원도 정선군 정선읍 정선로 1323  233804.0  26131.0  NaN    1
# 269         수정다방           강원도 고성군 거진읍 행랑골길 6  219901.0  24714.0  NaN  NaN
# ...          ...                          ...       ...      ...  ...  ...
# 96890        NaN         충청북도 청주시 흥덕구 부모산로 93  361825.0  28362.0  NaN    1
# 96891  농협생명화재중앙회         충청북도 청주시 청원구 상당로 305  363807.0  28479.0  NaN    1
# 96892        NaN          충청북도 청주시 청원구 사뜸로 24  363821.0  28349.0  NaN    1
# 96905        NaN           충청북도 충주시 호암수청1로 53  380967.0  27502.0  NaN    2
# 96907        NaN  충청북도 청주시 흥덕구 오송읍 오송생명8로 191  361953.0  28222.0  NaN    1
#
#        호정보          경도         위도
# 13     NaN  128.919456  37.759315
# 39     NaN  127.958442  37.319958
# 56     NaN  128.586322  38.191024
# 83     NaN  128.660805  37.379458
# 269    NaN  128.456166  38.447977
# ...    ...         ...        ...
# 96890  NaN  127.414859  36.635668
# 96891  NaN  127.488217  36.655544
# 96892  NaN  127.483190  36.664642
# 96905  NaN  127.925491  36.957421
# 96907  NaN  127.319401  36.619876
#
# [118168 rows x 39 columns]

# %% [markdown]
# ### 1-3 특정한 카페만 조회하기
# 1-2에서 만든 Data Frame에서 우리는 전국 카페의 정보를 얻어냈습니다. 이제 이중에서 `마포구`에 위치한 `스타벅스`의 데이터만 조회하는 코드를 작성해주세요.
#
# - 가만 데이터를 살펴보니 상호명이 순수하게 `스타벅스`인 곳만 있는 게 아니라 `스타벅스 ~~점`처럼 지점 이름이 포함된 곳도 있습니다. 이런 스타벅스도 조회하려면 어떻게 해야할까요?
#
# <br>
#
# ```python
# """~ Codes from 1-2"""
#
# concat_df = > HERE YOUR CODE!!
#
# concat_df = concat_df.reset_index(drop=True) # inplace 쓰셔도 됩니다~
# concat_df
# ```
#
# <br>
#
# 검색 힌트 : pandas indexing, pandas fency indexing, python str contains, python str startswith
#
# <br>
#
# _예시_
# ![](./1-3answer.png)

# %%
import pandas as pd
from glob import glob
import warnings
warnings.filterwarnings('ignore') # 경고 메세지를 출력 안 하는 코드입니다.

base_dir = "03_EDA_실습데이터" # 알집 풀어주신 곳 폴더를 넣으시면 됩니다.
file_lst = glob(base_dir + "/*.csv")

df_lst = []

for dir in file_lst:
    df = pd.read_csv(dir)
    df_lst.append(df)

concat_df = pd.concat(df_lst)

coffee_shops = concat_df.loc[concat_df['상권업종중분류명'] == '커피점/카페',:]
mapo_starbucks = coffee_shops[coffee_shops['상호명'].str.startswith('스타벅스') & coffee_shops['도로명주소'].str.contains('마포구')]
print(mapo_starbucks)
# Out:
#           상가업소번호                   상호명         지점명 상권업종대분류코드 상권업종대분류명  \
# 4627    23455005                  스타벅스        서강대점         Q       음식
# 19815   12111546                  스타벅스       마포염리점         Q       음식
# 22220   20385282        스타벅스상암DMC센트럴몰점  상암DMC센트럴몰점         Q       음식
# 23916   20078185            스타벅스홍대삼거리점      홍대삼거리점         Q       음식
# 25704   25521592           스타벅스합정메세나몰점     합정메세나몰점         Q       음식
# 30830   12452096                  스타벅스      서강대흥역점         Q       음식
# 32763   11805472                  스타벅스     서교동사거리점         Q       음식
# 44045   25815591                  스타벅스        홍대역점         Q       음식
# 48948   16729269                  스타벅스     서강대프라자점         Q       음식
# 51163   25896387           스타벅스월드컵경기장점     월드컵경기장점         Q       음식
# 53479   20014791                  스타벅스        망원역점         Q       음식
# 56051   25222901                  스타벅스         서교점         Q       음식
# 79484   26262381                  스타벅스        상수역점         Q       음식
# 90931   11970440                  스타벅스         합정점         Q       음식
# 92869   11931132            스타벅스마포이마트점      마포이마트점         Q       음식
# 93829   11934266                  스타벅스      신촌오거리점         Q       음식
# 118884  12081650            스타벅스커피마포염리         NaN         Q       음식
# 125119  16058450                  스타벅스     마포경찰서후문         Q       음식
# 160791  12430956           스타벅스서강광흥창역점     서강광흥창역점         Q       음식
# 165074  23353775  스타벅스상암디지털큐브점상암디지털큐브점    상암디지털큐브점         Q       음식
# 187609  20016042            스타벅스마포트라팰점      마포트라팰점         Q       음식
# 224579  15961548                  스타벅스    홍대공항철도역점         Q       음식
# 236086  16593461                  스타벅스      마포용강동점         Q       음식
# 236518  20595780           스타벅스마포일진빌딩점     마포일진빌딩점         Q       음식
# 244183  26266447                  스타벅스      상암MBC점         Q       음식
# 249174  20000283          스타벅스마포아크로타워점    마포아크로타워점         Q       음식
#
#        상권업종중분류코드 상권업종중분류명 상권업종소분류코드     상권업종소분류명 표준산업분류코드  ...  \
# 4627         Q12   커피점/카페    Q12A01  커피전문점/카페/다방   I56220  ...
# 19815        Q12   커피점/카페    Q12A01  커피전문점/카페/다방   I56220  ...
# 22220        Q12   커피점/카페    Q12A01  커피전문점/카페/다방   I56220  ...
# 23916        Q12   커피점/카페    Q12A01  커피전문점/카페/다방   I56220  ...
# 25704        Q12   커피점/카페    Q12A01  커피전문점/카페/다방   I56220  ...
# 30830        Q12   커피점/카페    Q12A01  커피전문점/카페/다방   I56220  ...
# 32763        Q12   커피점/카페    Q12A01  커피전문점/카페/다방   I56220  ...
# 44045        Q12   커피점/카페    Q12A01  커피전문점/카페/다방   I56220  ...
# 48948        Q12   커피점/카페    Q12A01  커피전문점/카페/다방   I56220  ...
# 51163        Q12   커피점/카페    Q12A01  커피전문점/카페/다방   I56220  ...
# 53479        Q12   커피점/카페    Q12A01  커피전문점/카페/다방   I56220  ...
# 56051        Q12   커피점/카페    Q12A01  커피전문점/카페/다방   I56220  ...
# 79484        Q12   커피점/카페    Q12A01  커피전문점/카페/다방   I56220  ...
# 90931        Q12   커피점/카페    Q12A01  커피전문점/카페/다방   I56220  ...
# 92869        Q12   커피점/카페    Q12A01  커피전문점/카페/다방   I56220  ...
# 93829        Q12   커피점/카페    Q12A01  커피전문점/카페/다방   I56220  ...
# 118884       Q12   커피점/카페    Q12A01  커피전문점/카페/다방   I56220  ...
# 125119       Q12   커피점/카페    Q12A01  커피전문점/카페/다방   I56220  ...
# 160791       Q12   커피점/카페    Q12A01  커피전문점/카페/다방   I56220  ...
# 165074       Q12   커피점/카페    Q12A01  커피전문점/카페/다방   I56220  ...
# 187609       Q12   커피점/카페    Q12A01  커피전문점/카페/다방   I56220  ...
# 224579       Q12   커피점/카페    Q12A01  커피전문점/카페/다방   I56220  ...
# 236086       Q12   커피점/카페    Q12A01  커피전문점/카페/다방   I56220  ...
# 236518       Q12   커피점/카페    Q12A01  커피전문점/카페/다방   I56220  ...
# 244183       Q12   커피점/카페    Q12A01  커피전문점/카페/다방   I56220  ...
# 249174       Q12   커피점/카페    Q12A01  커피전문점/카페/다방   I56220  ...
#
#                            건물관리번호         건물명                  도로명주소  \
# 4627    1144011100100630014007662         거구장       서울특별시 마포구 백범로 23
# 19815   1144010900101680009006616       재화스퀘어      서울특별시 마포구 독막로 311
# 22220   1144012700101360006028901  DMC이안상암1단지    서울특별시 마포구 월드컵북로 375
# 23916   1144011500100860022009107         NaN      서울특별시 마포구 와우산로 64
# 25704   1144012000104900000000001      메세나폴리스       서울특별시 마포구 양화로 45
# 30830   1144010800101110001023336        성호빌딩       서울특별시 마포구 백범로 89
# 32763   1144012000103740020010455         NaN      서울특별시 마포구 양화로 105
# 44045   1144012100101590001011730        상진빌딩      서울특별시 마포구 양화로 165
# 48948   1144010800100220060004795       서강대학교       서울특별시 마포구 백범로 35
# 51163   1144012500105290016017988     월드컵주경기장     서울특별시 마포구 월드컵로 240
# 53479   1144012000104750013021266        원천빌딩      서울특별시 마포구 월드컵로 74
# 56051   1144012000103950166010786         NaN       서울특별시 마포구 양화로 78
# 79484   1144011500103290001020244         NaN       서울특별시 마포구 독막로 88
# 90931   1144012200100000000000002    마포한강푸르지오    서울특별시 마포구 월드컵로1길 14
# 92869   1144010300100690002000001    대우월드마크마포      서울특별시 마포구 백범로 212
# 93829   1144011000100540001007321         NaN    서울특별시 마포구 신촌로16길 10
# 118884  1144010900101680009006616    국민건강보험공단      서울특별시 마포구 독막로 311
# 125119  1144010100106180019023903  마포센텀슬로우스퀘어  서울특별시 마포구 마포대로 173-14
# 160791  1144011400101300000024626         NaN       서울특별시 마포구 서강로 69
# 165074  1144012700116470000000001         NaN      서울특별시 마포구 상암산로 34
# 187609  1144010100107380000002804   마포트라팰리스2차     서울특별시 마포구 마포대로 201
# 224579  1144012100101660001011788         NaN      서울특별시 마포구 양화로 178
# 236086  1144010500101120002003811      근린생활시설      서울특별시 마포구 토정로 295
# 236518  1144010400100500001003217        일진빌딩      서울특별시 마포구 마포대로 45
# 244183  1144012700116030000000001     (주)문화방송      서울특별시 마포구 성암로 267
# 249174  1144010400105630000010646     마포아크로타워      서울특별시 마포구 마포대로 68
#
#            구우편번호   신우편번호  동정보  층정보  호정보          경도         위도
# 4627    121854.0  4108.0  NaN    1  NaN  126.937543  37.552426
# 19815   121749.0  4156.0  NaN  NaN  NaN  126.947463  37.543991
# 22220   121904.0  3908.0  NaN    1  NaN  126.890828  37.577397
# 23916   121828.0  4067.0  NaN    1  NaN  126.923259  37.550207
# 25704   121919.0  4036.0  NaN   -1  NaN  126.913937  37.551491
# 30830   121809.0  4111.0  NaN    1  NaN  126.941552  37.548255
# 32763   121894.0  4033.0  NaN    1  NaN  126.918561  37.553407
# 44045   121756.0  3995.0  NaN    1  NaN  126.923599  37.557202
# 48948   121808.0  4107.0  NaN  NaN  NaN  126.943045  37.551494
# 51163   121250.0  3932.0  NaN    1  NaN  126.897257  37.568276
# 53479   121896.0  4004.0  NaN    2  NaN  126.910706  37.555768
# 56051   121740.0  4043.0  NaN    1  NaN  126.916904  37.551374
# 79484   121829.0  4075.0  NaN    1  NaN  126.923207  37.547503
# 90931   121888.0  4024.0  NaN    1  NaN  126.912046  37.550041
# 92869   121030.0  4196.0  NaN    1  NaN  126.953346  37.542422
# 93829   121807.0  4057.0  NaN    1  NaN  126.934664  37.555167
# 118884  121749.0  4156.0  NaN    1  NaN  126.947463  37.543991
# 125119  121862.0  4130.0  NaN  NaN  NaN  126.953589  37.550993
# 160791  121881.0  4065.0  NaN    1  NaN  126.931679  37.549418
# 165074  121904.0  3909.0  NaN    1  NaN  126.889226  37.576301
# 187609  121858.0  4130.0  NaN    1  NaN  126.955507  37.552244
# 224579  121818.0  4051.0  NaN    2  NaN  126.925191  37.557496
# 236086  121875.0  4166.0  NaN  NaN  NaN  126.942206  37.541196
# 236518  121716.0  4167.0  NaN    1  NaN  126.946358  37.540467
# 244183  121904.0  3925.0  NaN    1  NaN  126.890966  37.581110
# 249174  121815.0  4168.0  NaN    1  NaN  126.949139  37.541456
#
# [26 rows x 39 columns]

# %% [markdown]
# ### 1-4 프렌차이즈 카페 조회해보기
# 마포구에 있는 스타벅스의 데이터를 모두 조회해봤습니다. 이제 스타벅스 뿐만 아니라, `투썸`, `이디야`, `할리스`, `메가커피`, `커피빈`에 대한 정보도 한번 가져와봅시다!
# 위에서 명시된 프렌차이즈 카페(스타벅스 포함)들의 마포구 내의 점포 수와, 입점 비율 정보가 담겨있는 Data Frame을 생성하는 코드를 작성해주세요.
#
# - 각 카페의 상호명은 아래 `cafe_lst`변수의 이름이 포함되어 있는 것을 기준으로 합니다.
#     - ex) 스타벅스홍대T동점 -> O , Starbucks홍대T동점 -> X
#
# <br>
#
# ```python
# """from 1-1 code's Data Frame!!"""
#
# mapo_cafes = ori_df[(ori_df['시군구명'] == "마포구") & (ori_df['상권업종중분류명'] == "커피점/카페")].reset_index(drop=True)
#
# tot_cafes = len(mapo_cafes)
#
# cafe_lst = ['스타벅스', "투썸플레이스", "이디야", "할리스", "메가커피", "커피빈"]
# nums = []
# ratio = []
#
# > HERE YOUR CODE!!
#
# mapo_cafe_info
# ```
#
# <br>
#
# 검색 힌트 : pandas indexing, pandas fency indexing, python str contains, python str startswith, python f-string, python string format
#
# <br>
#
# _예시_
# ![](./1-4answer.png)

# %%
import pandas as pd
from glob import glob
import warnings
warnings.filterwarnings('ignore') # 경고 메세지를 출력 안 하는 코드입니다.

base_dir = "03_EDA_실습데이터" # 알집 풀어주신 곳 폴더를 넣으시면 됩니다.
file_lst = glob(base_dir + "/*.csv")

df_lst = []

for dir in file_lst:
    df = pd.read_csv(dir)
    df_lst.append(df)

ori_df = pd.concat(df_lst)

mapo_cafes = ori_df[(ori_df['시군구명'] == "마포구") & (ori_df['상권업종중분류명'] == "커피점/카페")].reset_index(drop=True)

tot_cafes = len(mapo_cafes)

cafe_lst = ['스타벅스', "투썸플레이스", "이디야", "할리스", "메가커피", "커피빈"]
nums = []
ratio = []

for cafe in cafe_lst:
    num_cafe = len(mapo_cafes[mapo_cafes['상호명'].str.contains(cafe)])
    nums.append(num_cafe)

for n in nums:
    rate = (n/tot_cafes)*100
    ratio.append(f'{round(rate,2)}%')

data = {
    '프랜차이즈' : cafe_lst,
    '점포수' : nums,
    '입점 비율' : ratio
}

mapo_cafe_info = pd.DataFrame(data)
print(mapo_cafe_info)
# Out:
#     프랜차이즈  점포수  입점 비율
# 0    스타벅스   26  1.52%
# 1  투썸플레이스   18  1.05%
# 2     이디야   21  1.23%
# 3     할리스   12   0.7%
# 4    메가커피    7  0.41%
# 5     커피빈    7  0.41%

# %% [markdown]
# ### 1-5 시각화하기
# 데이터프레임으로만 나타내면 읽을 수는 있겠지만, 너무 오래 보면 눈이 피곤할 것같습니다. 1-4에서 얻어낸 입점 비율을 간단하게 시각화하는 코드를 작성해주세요.
# 단, 입점비율이 가장 높은 프렌차이즈는 강조해서 표시해주세요.
#
# - 본 문제는 여러분이 배웠던 시각화 스킬 중에 가장 적절하다고 판단되는 방법을 사용해주세요. `bar plot`도 좋고, `pie chart`도 좋습니다 :)
#
# ```python
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# > HERE YOUR FREE CODE!!
#
# plt.show()
# ```
#
# <br>
#
# 검색 힌트 : matplotlib bar plot, matplotlib pie chart, matplotlib color

# %%
import pandas as pd
from glob import glob
import warnings
warnings.filterwarnings('ignore') # 경고 메세지를 출력 안 하는 코드입니다.

base_dir = "03_EDA_실습데이터" # 알집 풀어주신 곳 폴더를 넣으시면 됩니다.
file_lst = glob(base_dir + "/*.csv")

df_lst = []

for dir in file_lst:
    df = pd.read_csv(dir)
    df_lst.append(df)

ori_df = pd.concat(df_lst)

mapo_cafes = ori_df[(ori_df['시군구명'] == "마포구") & (ori_df['상권업종중분류명'] == "커피점/카페")].reset_index(drop=True)

tot_cafes = len(mapo_cafes)

cafe_lst = ['스타벅스', "투썸플레이스", "이디야", "할리스", "메가커피", "커피빈"]
nums = []
ratio = []

for cafe in cafe_lst:
    num_cafe = len(mapo_cafes[mapo_cafes['상호명'].str.contains(cafe)])
    nums.append(num_cafe)

for n in nums:
    rate = (n/tot_cafes)*100
    ratio.append(f'{round(rate,2)}%')

data = {
    '프랜차이즈' : cafe_lst,
    '점포수' : nums,
    '입점 비율' : ratio
}

mapo_cafe_info = pd.DataFrame(data)

import matplotlib.pyplot as plt
import seaborn as sns

plt.bar(data['프랜차이즈'],data['점포수'])
plt.title('카페 프랜차이즈 별 점포수 비교')
plt.show()
# Out:
#     프랜차이즈  점포수  입점 비율
# 0    스타벅스   26  1.52%
# 1  투썸플레이스   18  1.05%
# 2     이디야   21  1.23%
# 3     할리스   12   0.7%
# 4    메가커피    7  0.41%
# 5     커피빈    7  0.41%

# %% [markdown]
# ### 1-7 인사이트
# 우리는 간단한 데이터로, 간단한 EDA를 진행해봤습니다. 여러분은 어떤 인사이트를 얻어냈나요? 우리는 마포구의 카페 정보만 알아봤지만, 여러분이 살고 계시는 지역의 카페, 카페가 아니더라도 음식점의 입점 비율을 확인해보든가도 가능할 것같습니다.
#
# 여러분이 알고 싶은 정보를 뽑아내기 위해, 지역이나 업종을 달리해서 알아내보세요! 이런 걸 시도해볼 수 있을 거 같아요 :)
# - 서울시에서 스타벅스가 가장 많은 구는 어디인가요?
# - 서울시를 제외한 지역에서 가장 인기가 많은 프렌차이즈는 어디일까요?
# - 본인이 사는 혹은 고향의 상권 정보도 위의 과정으로 한번 알아볼까요?

# %% [markdown]
# # 2. 마케팅 데이터 EDA 해보기
# - 1부에선 데이터 자체를 뚝딱뚝딱 거리면서 그 안에서 우리가 얻을 수 있는 정보가 무엇이 있을지 생각해봤습니다.
# - 그럼 이제, 우리가 5주차부터 하게될 `Machine Learning`과 `Deep Learning` 모델링을 하기 전에, 데이터로부터 어떤 전략을 짤 수 있는지 한번 알아보겠습니다.
# - **❗❗물론❗❗** 우리는 EDA 단계만 하는 것이기 때문에, 모델링을 위한 데이터 전처리는 5주차부터 알아볼 거예요 :) 지금은 그냥 가볍게~ 어떤 정보들을 확인해야 하는지만 알아보는 과정으로 이해해주세요 ㅎㅎ

# %% [markdown]
# ### 2-1 데이터 읽어오기
# [이곳](https://www.kaggle.com/datasets/vetrirah/customer)에서 데이터를 받아 데이터를 읽어오세요. Train Data만 읽어오시면 됩니다.
#
# ```python
# import pandas as pd
#
# > HERE YOUR CODE!!
#
# df
# ```

# %%
import pandas as pd

df = pd.read_csv('test.csv')
print(df)
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 8063  464018    Male           No   22        No            NaN
# 8064  464685    Male           No   35        No      Executive
# 8065  465406  Female           No   33       Yes     Healthcare
# 8066  467299  Female           No   27       Yes     Healthcare
# 8067  461879    Male          Yes   37       Yes      Executive
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0            Low          4.0  Cat_4            D
# 1                 NaN        Average          3.0  Cat_4            A
# 2                 1.0            Low          1.0  Cat_6            B
# 3                 0.0           High          2.0  Cat_6            B
# 4                 NaN           High          6.0  Cat_6            A
# ...               ...            ...          ...    ...          ...
# 8063              0.0            Low          7.0  Cat_1            D
# 8064              3.0            Low          4.0  Cat_4            D
# 8065              1.0            Low          1.0  Cat_6            D
# 8066              1.0            Low          4.0  Cat_6            B
# 8067              0.0        Average          3.0  Cat_4            B
#
# [8068 rows x 11 columns]

# %% [markdown]
# ### 2-2 결측치 확인하기
# ❗잠깐❗
# `!pip insatll missingno`로 `missingno`를 설치해주세요!
#
# 불러온 데이터의 Column 별 결측치(Missing Value) 정보를 출력하는 코드와
# `missingno`를 활용하여 결측치를 시각화해보세요.
#
# ```python
# import pandas as pd
# import missingno as msno
#
# > Codes that print Missing Values
#
# > Codes that visualize Missing Values with `missingno`
# ```
#
# 검색 힌트 : python missingno, missingno matrix, missingno bar, pandas isnull()
#
# _예시_
# ![](./2-2answer.png)
# ![](./2-2answer2.png)

# %%
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt


df = pd.read_csv('test.csv')

print(df.isnull().sum())

fig,axs = plt.subplots(2,1,figsize=(12,10))
msno.matrix(df,ax=axs[0])
msno.bar(df,ax=axs[1])
plt.show()
# Out:
# ID                   0
# Gender               0
# Ever_Married        50
# Age                  0
# Graduated           24
# Profession          38
# Work_Experience    269
# Spending_Score       0
# Family_Size        113
# Var_1               32
# dtype: int64

# %% [markdown]
# ### 2-3 Distribution Check
# 2-1에서 불러온 Data Frame의 Column별 분포를 확인할 수 있는 코드를 작성해주세요.
# - 단, _예시_ 처럼 한 눈에 전체 Column의 분포를 확인할 수 있게 시각화해보세요.
# - 데이터의 분포를 확인하는 것만으로도, 이상치를 어떻게 대처해야할지 플랜을 세울 수 있습니다 :)
#
# ```python
# import pandas as pd
# import matploblib.pyplot as plt
# import seaborn as sns
#
# > HERE YOUR CODE!!
# ```
#
# <br>
#
# 검색 힌트 : seaborn countplot, seaborn distplot seaborn kdeplot, matplotlib for문 여러개 그리기, plt.subplots_adjust, plt.style("ggplot")
#
# <br>
#
# _예시_
# ![](./2-3answer.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df= pd.read_csv('test.csv')

fig,axs=plt.subplots(3,4)

sns.countplot(x='Gender',data=df,ax=axs[0][0])
sns.countplot(x="Ever_Married",data=df,ax=axs[0][1])
sns.distplot(df['Age'],ax=axs[0][2])

idx = 3
for i in range(7):
    sns.countplot(x=f'{df.columns[idx]}',data = df,ax=axs[idx//4][idx%4])
    idx+=1

plt.show()

# %% [markdown]
# ### 2-4 Correlation Check
# 변수간 상관관계가 무엇일까요? 상관관계가 무엇인지 여러분만의 답을 적어주세요.
# 추가적으로, 2-1에서 불러온 Data Frame의 Column 간 `상관관계`를 시각화하여 확인할 수 있는 코드를 작성하고, 이를 해석해보세요.
#
#
# ```python
# import pandas as pd
# import matploblib.pyplot as plt
# import seaborn as sns
#
# > HERE YOUR CODE!!
# ```
#
# <br>
#
# 검색 힌트 : seaborn heatmap, seaborn heatmap parameters, seaborn mask
#
# <br>
#
# _예시_
# ![](./2-4answer.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('test.csv')
sns.heatmap(data= df.corr())
# Out:
# <Axes: >

# %% [markdown]
# # 3주차 종료
# - EDA 문제를 모두 해결하신 여러분 고생많으셨습니다. EDA는 초입에서 말씀 드린 것처럼, 그 자체로 데이터를 분석할 수 있는 강력한 스킬이 될 수 있고, 추후에 우리가 문제를 풀어볼 모델링의 방향성을 잡는 데에도 쓰일 수 있답니다 :)
# - 여러분들이 이번 컨텐츠를 해결하시면서 Raw Data 가공법, 그 안에서 쓸만한 데이터를 추출할 수 있는 방법, 그리고 그것을 다른 사람들에게 전달하는 스킬을 얻으셨으면 합니다.
# - 질문은 언제든 `discord 채널`을 활용해주세요!
#
# # 숙제
# - 역시 숙제가 있습니다.
# - 여러분은 오늘 공공데이터를 여러분 나름의 방식으로 EDA해보셨습니다. 오늘 EDA하신 내용과 그 과정을 여러분들의 블로그에 정리해서 올려주세요.
# - 데이터의 자료형이나 특성이 이러해서 어떠한 방법을 사용했는지, 그런 특성상 어떤 시각화 기법을 이용하는 것이 좋겠다고 판단했는지를 적다보면, 단순히 글을 올린다는 의미보다 추상적이었던 지식과 경험을 여러분들만의 언어로 구체화 하고 있다는 것을 느끼실 수 있을 겁니다.
# - 이 숙제 역시 정답은 없습니다! 여러분만의 EDA를 블로그에 업로드 해주세요!
#
#
# ## 심화 숙제
# 🚀 다른 공공데이터를 활용하시면 여러분 실력 향상에 더 좋습니다 :) [이곳](https://www.data.go.kr/)에서 여러분들 입맛에 맞는 데이터를 선정하신 뒤, EDA를 하시는 것도 큰 도움이 될 거예요!
# - 공공데이터를 선정하신 후에 여러분들만의 EDA를 진행해보세요! 그리고 그 결과를 블로그에 정리해보세요! 이 과정을 거치시면 여러분들의 실력이 굉----장히 올라있을 겁니다!
# - 심화 숙제를 클리어하신 분들은 `@자기혁명왕`에게 블로그 링크와 함께 DM을 보내주세요! (나중에 우수 스터디원 선정에 반영될 수도~?)
